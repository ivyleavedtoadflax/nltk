# %%
# %matplotlib inline

import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.similar('monstrous')
# Out:
# fearless subtly untoward horrible few pitiable loving vexatious
# christian lamentable determined trustworthy perilous gamesome wise
# mystifying modifies puzzled abundant curious

# %% [markdown]
# `common_contexts()` needs to be passed a list

# %%
text1.common_contexts(['monstrous'])
# Out:
# most_size the_pictures most_and this_cabinet more_stories a_size
# what_cannibal that_bulk a_fable of_clubs

# %%
text2.dispersion_plot(['monstrous'])

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# ## Counting vocab

# %%
len(text3)
# Out:
# 44764

# %% [markdown]
# Converting to `set` makes the items in the list unique! Note that this includes punctuation!

# %%
sorted(set(text3))[10:20]
# Out:
# [';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech']

# %%
len(set(text3))
# Out:
# 2789

# %% [markdown]
# Ratio of original types (words) to total words

# %%
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %% [markdown]
# How often does a word appear in a text

# %%
text3.count("smote")
# Out:
# 5

# %% [markdown]
# What percentage of a text is taken up by a particular word?

# %%
100 * text4.count('a') / len(text4)
# Out:
# 1.4643016433938312

# %% [markdown]
# Convert these into functions:

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

def percentage(text, typ): 
    return 100 * text.count(typ) / len(text)

# %%
lexical_diversity(text1)
# Out:
# 0.07406285585022564

# %%
percentage(text4,'a')
print([round(lexical_diversity(i),3) for i in [text1,text2,text3,text4,text5]])
text5
# Out:
# [0.074, 0.048, 0.062, 0.067, 0.135]
# <Text: Chat Corpus>

# %%
text4[173]
# Out:
# 'awaken'

# %%
text4.index('awaken')
# Out:
# 173

# %%
fdist1 = FreqDist(text1)
fdist1
# Out:
# FreqDist({'bold': 17,
#           'basis': 3,
#           'skrimshander': 1,
#           'intemperately': 1,
#           ':--"': 1,
#           'ultimate': 7,
#           'Hither': 1,
#           'View': 2,
#           'brack': 1,
#           'unbutton': 1,
#           'commence': 2,
#           'yore': 2,
#           'reverend': 5,
#           'misanthrope': 1,
#           'phrenological': 2,
#           'bat': 1,
#           'savagery': 1,
#           'Says': 2,
#           'Fast': 16,
#           'moulded': 2,
#           'larceny': 1,
#           'Rains': 1,
#           'billows': 20,
#           'tarts': 1,
#           'inwards': 3,
#           'term': 10,
#           'works': 30,
#           'invincible': 1,
#           'upliftings': 1,
#           'preferred': 1,
#           'applying': 1,
#           'casts': 3,
#           'northern': 7,
#           'blast': 10,
#           'Spin': 1,
#           'flume': 1,
#           'considerably': 9,
#           'bass': 1,
# ...
